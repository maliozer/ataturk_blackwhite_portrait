# %% [markdown]
# ##Atatürk's Portrait Black & White
# ###10 November 1938
#
# #####Published on **10.Nov.2019 by** **[@touch.to.start](https://www.instagram.com/touch.to.start/)** & **[@mali.ozer](https://www.instagram.com/mali.ozer/)**

# %% [markdown]
# ####connecing with drive and importing modules

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/data/ataturk')

# %%
originalImage = cv2.imread('./ata_colored.jpg')

# %% [markdown]
# ####conver the image to gray scale in order to apply threshold operation

# %%
grayImage = cv2.cvtColor(originalImage, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ####applying binary threshold to grayscaled image

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 127, 255, cv2.THRESH_BINARY)

# %% [markdown]
# ####comparison between original and output images

# %%
#importing matplotlib
from matplotlib import pyplot as plt

#comparison between original and output images
plt.imshow(cv2.cvtColor(originalImage, cv2.COLOR_BGR2RGB))
plt.show()

plt.imshow(grayImage, cmap='gray')
plt.show()

plt.imshow(blackAndWhiteImage, cmap='gray')
plt.show()
